# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("IcebergMiniProject") \
    .config("spark.sql.catalog.my_catalog", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.my_catalog.catalog-impl", "org.apache.iceberg.rest.RESTCatalog") \
    .config("spark.sql.catalog.my_catalog.uri", "http://rest:8181") \
    .config("spark.sql.catalog.my_catalog.warehouse", "s3://warehouse/") \
    .config("spark.sql.catalog.my_catalog.io-impl", "org.apache.iceberg.aws.s3.S3FileIO") \
    .config("spark.sql.catalog.my_catalog.s3.endpoint", "http://minio:9000") \
    .config("spark.sql.catalog.my_catalog.s3.access-key-id", "admin") \
    .config("spark.sql.catalog.my_catalog.s3.secret-access-key", "password") \
    .config("spark.sql.catalog.my_catalog.s3.region", "us-east-1") \
    .getOrCreate()

spark
# Out:
# 26/01/18 14:23:57 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5beb74be2801:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql("SHOW CATALOGS").show()
# Out:
# +-------------+
# |      catalog|
# +-------------+
# |         demo|
# |spark_catalog|
# +-------------+

# %%
spark.sql("""
CREATE DATABASE IF NOT EXISTS demo
""")
# Out:
# DataFrame[]

# %%
spark.sql("SHOW DATABASES IN demo").show()
# Out:
# +----------+
# | namespace|
# +----------+
# |default_db|
# +----------+

# %%
spark.sql("""
CREATE DATABASE demo.default_db
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
CREATE TABLE demo.default_db.users (
    user_id INT,
    name STRING,
    country STRING,
    created_at TIMESTAMP
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
INSERT INTO demo.default_db.users VALUES
(1, 'Ali', 'PK', current_timestamp()),
(2, 'John', 'US', current_timestamp())
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
""").show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      1| Ali|     PK|2026-01-18 14:30:...|
# |      2|John|     US|2026-01-18 14:30:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("""
SELECT 
  snapshot_id,
  parent_id,
  committed_at,
  operation
FROM demo.default_db.users.snapshots
ORDER BY committed_at
""").show(truncate=False)
# Out:
# +-------------------+---------+----------------------+---------+
# |snapshot_id        |parent_id|committed_at          |operation|
# +-------------------+---------+----------------------+---------+
# |1607397796109514243|NULL     |2026-01-18 14:30:21.42|append   |
# +-------------------+---------+----------------------+---------+

# %%
spark.sql("""
SELECT 
  snapshot_id,
  parent_id,
  committed_at,
  operation
FROM demo.default_db.users.snapshots
ORDER BY committed_at
""").show(truncate=False)
# Out:
# +-------------------+---------+----------------------+---------+
# |snapshot_id        |parent_id|committed_at          |operation|
# +-------------------+---------+----------------------+---------+
# |1607397796109514243|NULL     |2026-01-18 14:30:21.42|append   |
# +-------------------+---------+----------------------+---------+

# %%
spark.sql("""
INSERT INTO demo.default_db.users VALUES
(3, 'Sara', 'UK', current_timestamp())
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
UPDATE demo.default_db.users
SET country = 'UAE'
WHERE user_id = 1
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DELETE FROM demo.default_db.users
WHERE user_id = 2
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SELECT 
  snapshot_id,
  committed_at,
  operation
FROM demo.default_db.users.snapshots
ORDER BY committed_at
""").show(truncate=False)
# Out:
# +-------------------+-----------------------+---------+
# |snapshot_id        |committed_at           |operation|
# +-------------------+-----------------------+---------+
# |1607397796109514243|2026-01-18 14:30:21.42 |append   |
# |872424970877289686 |2026-01-18 14:32:02.38 |append   |
# |5738472431389787117|2026-01-18 14:32:16.755|overwrite|
# |3969833432834730559|2026-01-18 14:32:29.795|delete   |
# +-------------------+-----------------------+---------+

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
VERSION AS OF 5738472431389787117
""").show()
# Out:
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      1| Ali|    UAE|2026-01-18 14:30:...|
# |      3|Sara|     UK|2026-01-18 14:32:...|
# |      2|John|     US|2026-01-18 14:30:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
TIMESTAMP AS OF '2026-01-18 14:31:00'
""").show()
# Out:
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      1| Ali|     PK|2026-01-18 14:30:...|
# |      2|John|     US|2026-01-18 14:30:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
VERSION AS OF 1607397796109514243
EXCEPT
SELECT * FROM demo.default_db.users
""").show()
# Out:
# [Stage 16:>                                                         (0 + 1) / 1]
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      2|John|     US|2026-01-18 14:30:...|
# |      1| Ali|     PK|2026-01-18 14:30:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
""").show()
# Out:
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      1| Ali|    UAE|2026-01-18 14:30:...|
# |      3|Sara|     UK|2026-01-18 14:32:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("""
DESCRIBE TABLE demo.default_db.users
""").show(truncate=False)
# Out:
# +----------+---------+-------+
# |col_name  |data_type|comment|
# +----------+---------+-------+
# |user_id   |int      |NULL   |
# |name      |string   |NULL   |
# |country   |string   |NULL   |
# |created_at|timestamp|NULL   |
# +----------+---------+-------+

# %%
spark.sql("""
ALTER TABLE demo.default_db.users
ADD COLUMN email STRING
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.default_db.users
""").show(truncate=False)
# Out:
# +----------+---------+-------+
# |col_name  |data_type|comment|
# +----------+---------+-------+
# |user_id   |int      |NULL   |
# |name      |string   |NULL   |
# |country   |string   |NULL   |
# |created_at|timestamp|NULL   |
# |email     |string   |NULL   |
# +----------+---------+-------+

# %%
spark.sql("""
SELECT snapshot_id, committed_at, operation
FROM demo.default_db.users.snapshots
ORDER BY committed_at DESC
""").show(truncate=False)
# Out:
# +-------------------+-----------------------+---------+
# |snapshot_id        |committed_at           |operation|
# +-------------------+-----------------------+---------+
# |3969833432834730559|2026-01-18 14:32:29.795|delete   |
# |5738472431389787117|2026-01-18 14:32:16.755|overwrite|
# |872424970877289686 |2026-01-18 14:32:02.38 |append   |
# |1607397796109514243|2026-01-18 14:30:21.42 |append   |
# +-------------------+-----------------------+---------+

# %%
spark.sql("""
ALTER TABLE demo.default_db.users
RENAME COLUMN name TO full_name
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.default_db.users
""").show(truncate=False)
# Out:
# +----------+---------+-------+
# |col_name  |data_type|comment|
# +----------+---------+-------+
# |user_id   |int      |NULL   |
# |full_name |string   |NULL   |
# |country   |string   |NULL   |
# |created_at|timestamp|NULL   |
# |email     |string   |NULL   |
# +----------+---------+-------+

# %%
spark.sql("""
SELECT snapshot_id, operation
FROM demo.default_db.users.snapshots
ORDER BY committed_at DESC
""").show(truncate=False)
# Out:
# +-------------------+---------+
# |snapshot_id        |operation|
# +-------------------+---------+
# |3969833432834730559|delete   |
# |5738472431389787117|overwrite|
# |872424970877289686 |append   |
# |1607397796109514243|append   |
# +-------------------+---------+

# %%
spark.sql("""
ALTER TABLE demo.default_db.users
ALTER COLUMN country AFTER full_name
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.default_db.users
""").show(truncate=False)
# Out:
# +----------+---------+-------+
# |col_name  |data_type|comment|
# +----------+---------+-------+
# |user_id   |int      |NULL   |
# |full_name |string   |NULL   |
# |country   |string   |NULL   |
# |created_at|timestamp|NULL   |
# |email     |string   |NULL   |
# +----------+---------+-------+

# %%
spark.sql("""
SELECT user_id, full_name, country, email
FROM demo.default_db.users
""").show()
# Out:
# +-------+---------+-------+-----+
# |user_id|full_name|country|email|
# +-------+---------+-------+-----+
# |      3|     Sara|     UK| NULL|
# |      1|      Ali|    UAE| NULL|
# +-------+---------+-------+-----+

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
VERSION AS OF 872424970877289686
""").show()
# Out:
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      3|Sara|     UK|2026-01-18 14:32:...|
# |      1| Ali|     PK|2026-01-18 14:30:...|
# |      2|John|     US|2026-01-18 14:30:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
VERSION AS OF 1607397796109514243
""").show()
# Out:
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      1| Ali|     PK|2026-01-18 14:30:...|
# |      2|John|     US|2026-01-18 14:30:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("""
SELECT * FROM demo.default_db.users
TIMESTAMP AS OF '2026-01-18 14:31:00'
""").show()
# Out:
# +-------+----+-------+--------------------+
# |user_id|name|country|          created_at|
# +-------+----+-------+--------------------+
# |      1| Ali|     PK|2026-01-18 14:30:...|
# |      2|John|     US|2026-01-18 14:30:...|
# +-------+----+-------+--------------------+

# %%
spark.sql("SELECT * FROM demo.default_db.users.snapshots").show(truncate=False)
# Out:
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |committed_at           |snapshot_id        |parent_id          |operation|manifest_list                                                                                                |summary                                                                                                                                                                                                                                                                                                                                                                    |
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2026-01-18 14:30:21.42 |1607397796109514243|NULL               |append   |s3://warehouse/default_db/users/metadata/snap-1607397796109514243-1-91668742-6b4f-46e2-9db3-fdc593103966.avro|{spark.app.id -> local-1768745576410, added-data-files -> 2, added-records -> 2, added-files-size -> 2267, changed-partition-count -> 1, total-records -> 2, total-files-size -> 2267, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                           |
# |2026-01-18 14:32:02.38 |872424970877289686 |1607397796109514243|append   |s3://warehouse/default_db/users/metadata/snap-872424970877289686-1-9f364735-6083-48b7-b354-47cb3be3e328.avro |{spark.app.id -> local-1768745576410, added-data-files -> 1, added-records -> 1, added-files-size -> 1136, changed-partition-count -> 1, total-records -> 3, total-files-size -> 3403, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                           |
# |2026-01-18 14:32:16.755|5738472431389787117|872424970877289686 |overwrite|s3://warehouse/default_db/users/metadata/snap-5738472431389787117-1-ea7a1e2e-b530-447e-91d8-c105efbef4b5.avro|{spark.app.id -> local-1768745576410, added-data-files -> 1, deleted-data-files -> 1, added-records -> 1, deleted-records -> 1, added-files-size -> 1169, removed-files-size -> 1130, changed-partition-count -> 1, total-records -> 3, total-files-size -> 3442, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-01-18 14:32:29.795|3969833432834730559|5738472431389787117|delete   |s3://warehouse/default_db/users/metadata/snap-3969833432834730559-1-cdee9361-9641-4b44-aab5-6b510afcd1eb.avro|{spark.app.id -> local-1768745576410, deleted-data-files -> 1, deleted-records -> 1, removed-files-size -> 1137, changed-partition-count -> 1, total-records -> 2, total-files-size -> 2305, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                     |
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
spark.sql("DESCRIBE TABLE demo.default_db.users").show()
# Out:
# +----------+---------+-------+
# |  col_name|data_type|comment|
# +----------+---------+-------+
# |   user_id|      int|   NULL|
# | full_name|   string|   NULL|
# |   country|   string|   NULL|
# |created_at|timestamp|   NULL|
# |     email|   string|   NULL|
# +----------+---------+-------+

# %%
spark.sql("""
SELECT *
FROM demo.default_db.users.snapshots
ORDER BY committed_at DESC
""").show(truncate=False)
# Out:
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |committed_at           |snapshot_id        |parent_id          |operation|manifest_list                                                                                                |summary                                                                                                                                                                                                                                                                                                                                                                    |
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2026-01-18 14:32:29.795|3969833432834730559|5738472431389787117|delete   |s3://warehouse/default_db/users/metadata/snap-3969833432834730559-1-cdee9361-9641-4b44-aab5-6b510afcd1eb.avro|{spark.app.id -> local-1768745576410, deleted-data-files -> 1, deleted-records -> 1, removed-files-size -> 1137, changed-partition-count -> 1, total-records -> 2, total-files-size -> 2305, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                     |
# |2026-01-18 14:32:16.755|5738472431389787117|872424970877289686 |overwrite|s3://warehouse/default_db/users/metadata/snap-5738472431389787117-1-ea7a1e2e-b530-447e-91d8-c105efbef4b5.avro|{spark.app.id -> local-1768745576410, added-data-files -> 1, deleted-data-files -> 1, added-records -> 1, deleted-records -> 1, added-files-size -> 1169, removed-files-size -> 1130, changed-partition-count -> 1, total-records -> 3, total-files-size -> 3442, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-01-18 14:32:02.38 |872424970877289686 |1607397796109514243|append   |s3://warehouse/default_db/users/metadata/snap-872424970877289686-1-9f364735-6083-48b7-b354-47cb3be3e328.avro |{spark.app.id -> local-1768745576410, added-data-files -> 1, added-records -> 1, added-files-size -> 1136, changed-partition-count -> 1, total-records -> 3, total-files-size -> 3403, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                           |
# |2026-01-18 14:30:21.42 |1607397796109514243|NULL               |append   |s3://warehouse/default_db/users/metadata/snap-1607397796109514243-1-91668742-6b4f-46e2-9db3-fdc593103966.avro|{spark.app.id -> local-1768745576410, added-data-files -> 2, added-records -> 2, added-files-size -> 2267, changed-partition-count -> 1, total-records -> 2, total-files-size -> 2267, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                           |
# +-----------------------+-------------------+-------------------+---------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
spark.sql("""
SELECT snapshot_id, committed_at, operation, manifest_list
FROM demo.default_db.users.snapshots
ORDER BY committed_at DESC
""").show(truncate=False)
# Out:
# +-------------------+-----------------------+---------+-------------------------------------------------------------------------------------------------------------+
# |snapshot_id        |committed_at           |operation|manifest_list                                                                                                |
# +-------------------+-----------------------+---------+-------------------------------------------------------------------------------------------------------------+
# |3969833432834730559|2026-01-18 14:32:29.795|delete   |s3://warehouse/default_db/users/metadata/snap-3969833432834730559-1-cdee9361-9641-4b44-aab5-6b510afcd1eb.avro|
# |5738472431389787117|2026-01-18 14:32:16.755|overwrite|s3://warehouse/default_db/users/metadata/snap-5738472431389787117-1-ea7a1e2e-b530-447e-91d8-c105efbef4b5.avro|
# |872424970877289686 |2026-01-18 14:32:02.38 |append   |s3://warehouse/default_db/users/metadata/snap-872424970877289686-1-9f364735-6083-48b7-b354-47cb3be3e328.avro |
# |1607397796109514243|2026-01-18 14:30:21.42 |append   |s3://warehouse/default_db/users/metadata/snap-1607397796109514243-1-91668742-6b4f-46e2-9db3-fdc593103966.avro|
# +-------------------+-----------------------+---------+-------------------------------------------------------------------------------------------------------------+

# %%
spark.sql("""
SELECT manifest_list
FROM demo.default_db.users.snapshots
ORDER BY committed_at DESC
""").show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------+
# |manifest_list                                                                                                |
# +-------------------------------------------------------------------------------------------------------------+
# |s3://warehouse/default_db/users/metadata/snap-3969833432834730559-1-cdee9361-9641-4b44-aab5-6b510afcd1eb.avro|
# |s3://warehouse/default_db/users/metadata/snap-5738472431389787117-1-ea7a1e2e-b530-447e-91d8-c105efbef4b5.avro|
# |s3://warehouse/default_db/users/metadata/snap-872424970877289686-1-9f364735-6083-48b7-b354-47cb3be3e328.avro |
# |s3://warehouse/default_db/users/metadata/snap-1607397796109514243-1-91668742-6b4f-46e2-9db3-fdc593103966.avro|
# +-------------------------------------------------------------------------------------------------------------+

# %%
spark.sql("""
SELECT summary
FROM demo.default_db.users.snapshots
ORDER BY committed_at DESC
""").show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |summary                                                                                                                                                                                                                                                                                                                                                                    |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{spark.app.id -> local-1768745576410, deleted-data-files -> 1, deleted-records -> 1, removed-files-size -> 1137, changed-partition-count -> 1, total-records -> 2, total-files-size -> 2305, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                     |
# |{spark.app.id -> local-1768745576410, added-data-files -> 1, deleted-data-files -> 1, added-records -> 1, deleted-records -> 1, added-files-size -> 1169, removed-files-size -> 1130, changed-partition-count -> 1, total-records -> 3, total-files-size -> 3442, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |{spark.app.id -> local-1768745576410, added-data-files -> 1, added-records -> 1, added-files-size -> 1136, changed-partition-count -> 1, total-records -> 3, total-files-size -> 3403, total-data-files -> 3, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                           |
# |{spark.app.id -> local-1768745576410, added-data-files -> 2, added-records -> 2, added-files-size -> 2267, changed-partition-count -> 1, total-records -> 2, total-files-size -> 2267, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}                                                                           |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
spark.sql("""
SELECT
    committed_at,
    snapshot_id,
    parent_id,
    operation,
    summary['added-records'] AS added_records,
    summary['deleted-records'] AS deleted_records,
    summary['total-records'] AS total_records,
    summary['added-data-files'] AS added_files,
    summary['deleted-data-files'] AS deleted_files
FROM demo.default_db.users.snapshots
ORDER BY committed_at DESC
""").show(truncate=False)
# Out:
# +-----------------------+-------------------+-------------------+---------+-------------+---------------+-------------+-----------+-------------+
# |committed_at           |snapshot_id        |parent_id          |operation|added_records|deleted_records|total_records|added_files|deleted_files|
# +-----------------------+-------------------+-------------------+---------+-------------+---------------+-------------+-----------+-------------+
# |2026-01-18 14:32:29.795|3969833432834730559|5738472431389787117|delete   |NULL         |1              |2            |NULL       |1            |
# |2026-01-18 14:32:16.755|5738472431389787117|872424970877289686 |overwrite|1            |1              |3            |1          |1            |
# |2026-01-18 14:32:02.38 |872424970877289686 |1607397796109514243|append   |1            |NULL           |3            |1          |NULL         |
# |2026-01-18 14:30:21.42 |1607397796109514243|NULL               |append   |2            |NULL           |2            |2          |NULL         |
# +-----------------------+-------------------+-------------------+---------+-------------+---------------+-------------+-----------+-------------+

# %%
snapshot_df = spark.table("demo.default_db.users.snapshots")
summary_keys = ["added-records", "deleted-records", "total-records", "added-data-files", "deleted-data-files"]
for key in summary_keys:
    snapshot_df = snapshot_df.withColumn(key.replace("-", "_"), snapshot_df.summary[key])
snapshot_df.select("committed_at", "snapshot_id", "operation", *[k.replace("-", "_") for k in summary_keys]).show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 4
#       2 summary_keys = ["added-records", "deleted-records", "total-records", "added-data-files", "deleted-data-files"]
#       3 for key in summary_keys:
# ----> 4     snapshot_df = snapshot_df.withColumn(key.replace("-", "_"), snapshot_df.summary[key])
#       5 snapshot_df.select("committed_at", "snapshot_id", "operation", *[k.replace("-", "_") for k in summary_keys]).show(truncate=False)
#
# TypeError: 'method' object is not subscriptable

# %%
from pyspark.sql.functions import col

# Load snapshots table
snapshot_df = spark.table("demo.default_db.users.snapshots")

# Keys you want to extract from summary map
summary_keys = ["added-records", "deleted-records", "total-records", "added-data-files", "deleted-data-files"]

# Extract each key using getItem()
for key in summary_keys:
    snapshot_df = snapshot_df.withColumn(key.replace("-", "_"), col("summary").getItem(key))

# Select columns and show neatly
snapshot_df.select(
    "committed_at",
    "snapshot_id",
    "parent_id",
    "operation",
    *[k.replace("-", "_") for k in summary_keys],
    "manifest_list"
).orderBy(col("committed_at").desc()).show(truncate=False)
# Out:
# +-----------------------+-------------------+-------------------+---------+-------------+---------------+-------------+----------------+------------------+-------------------------------------------------------------------------------------------------------------+
# |committed_at           |snapshot_id        |parent_id          |operation|added_records|deleted_records|total_records|added_data_files|deleted_data_files|manifest_list                                                                                                |
# +-----------------------+-------------------+-------------------+---------+-------------+---------------+-------------+----------------+------------------+-------------------------------------------------------------------------------------------------------------+
# |2026-01-18 14:32:29.795|3969833432834730559|5738472431389787117|delete   |NULL         |1              |2            |NULL            |1                 |s3://warehouse/default_db/users/metadata/snap-3969833432834730559-1-cdee9361-9641-4b44-aab5-6b510afcd1eb.avro|
# |2026-01-18 14:32:16.755|5738472431389787117|872424970877289686 |overwrite|1            |1              |3            |1               |1                 |s3://warehouse/default_db/users/metadata/snap-5738472431389787117-1-ea7a1e2e-b530-447e-91d8-c105efbef4b5.avro|
# |2026-01-18 14:32:02.38 |872424970877289686 |1607397796109514243|append   |1            |NULL           |3            |1               |NULL              |s3://warehouse/default_db/users/metadata/snap-872424970877289686-1-9f364735-6083-48b7-b354-47cb3be3e328.avro |
# |2026-01-18 14:30:21.42 |1607397796109514243|NULL               |append   |2            |NULL           |2            |2               |NULL              |s3://warehouse/default_db/users/metadata/snap-1607397796109514243-1-91668742-6b4f-46e2-9db3-fdc593103966.avro|
# +-----------------------+-------------------+-------------------+---------+-------------+---------------+-------------+----------------+------------------+-------------------------------------------------------------------------------------------------------------+
